# %% [markdown]
# # 介绍
#
# 这是一个私人 Jupyter lab 服务器.

# %% [markdown]
#  示例:

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
x = np.linspace(0, 2*np.pi, 256)
y = np.sin(x)
plt.plot(x,y)
plt.savefig("sin.eps")
plt.savefig("sin.jpg")
plt.show()

# %% [markdown]
# ## Latex 公式
#
# 选中一个 cell, 按 Esc 键, 再按 M 键, 即可将 cell 变为 Markdown 格式. 反之 Esc -> Y 变回 code 格式.
#
# 示例:
#
# $$
# \mathrm{i}\hbar \frac{\partial}{\partial t} \psi = \left[ -\frac{\hbar^2}{2m}\nabla^2 + V\right]\psi
# $$

# %% [markdown]
# # 免责声明
#
# 1. 本服务不用于商业用途, 仅用于个人学习和测试程序.
#
# 2. 本服务器随时可能到期(最近到 2019-11-11 19:47)或者崩溃, 请备份好重要的程序. 我也会不定期备份到我的 Github: https://github.com/phyer219/jupyter_notebook_backup
#
# 3. 有任何疑问请联系站长 Email: zeqing6688@126.com .
